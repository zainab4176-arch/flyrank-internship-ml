# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/zainab4176-arch/flyrank-internship-ml/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
# **Task Type:** Scoring
#
# My lane is Content Refresh Opportunity Scoring. The ML task type is scoring because the goal is to assign each webpage a refresh opportunity score based on its performance data. Pages with higher scores can then be ranked and reviewed first by the SEO/content team.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# **Target/Proxy:** Refresh Opportunity Score
#
# The model aims to predict a refresh opportunity score for each webpage. The dataset does not contain a direct "needs refresh" label, so the prediction is based on proxy signals such as search volume, impressions, CTR, and ranking. These observed performance metrics help estimate which pages should be reviewed first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# **Success Metric:** Precision@20
#
# Precision@20 is an appropriate success metric because it measures how many of the top 20 webpages recommended by the model are truly good candidates for content refresh. A higher Precision@20 means the SEO team can focus on the most valuable pages first, making the recommendations more useful for decision-support.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# **Unit of Analysis:** One webpage
#
# Each row in the dataframe represents one webpage. The columns contain performance-related information such as search volume, impressions, CTR, rankings, and other features that help estimate the refresh opportunity for that webpage.

# %%
import os
import subprocess
import pandas as pd
# Clone the repository if it is not already present
if not os.path.exists("flyrank-ml-internship-starter"):
    subprocess.run([
        "git", "clone", "--depth", "1",
        "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
    ], check=True)
# Load the starter dataset
df = pd.read_csv(
    "flyrank-ml-internship-starter/data/raw/content_refresh_anonymized.csv"
)

# Show the first 5 rows
df.head()
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# **Why ML is Appropriate**
#
# A fixed rule cannot accurately identify the best pages for content refresh because webpage performance depends on multiple factors, not just one. Features such as search volume, impressions, CTR, average position, engagement rate, and trend direction interact in different ways. Machine learning can learn patterns from these combined features and provide more reliable, decision-support recommendations for prioritizing pages to review.

# %%
# Show the columns available in the dataset
print(df.columns.tolist())
# Out:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x]  Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
